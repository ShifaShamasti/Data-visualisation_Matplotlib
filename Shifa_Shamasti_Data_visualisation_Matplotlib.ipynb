# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
Stps=pd.read_csv("50_Startups.csv")
#type of STPS
print('Stps has type',type(Stps)) 
#info of dataframe
print(Stps.info())
#description
Stps.describe()
# Out:
# Stps has type <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 5 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   R&D Spend        45 non-null     float64
#  1   Administration   46 non-null     float64
#  2   Marketing Spend  48 non-null     float64
#  3   State            46 non-null     object
#  4   Profit           34 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB
# None
#            R&D Spend  Administration  Marketing Spend         Profit
# count      45.000000       46.000000        48.000000      34.000000
# mean    73382.444444   121952.295000    200834.512917  112148.650882
# std     46351.093750    28090.528796    123457.377487   40040.847823
# min         0.000000    51283.140000         0.000000   14681.400000
# 25%     38558.510000   106483.065000    115395.745000   90138.902500
# 50%     73994.560000   123467.895000    203322.230000  107978.190000
# 75%    100671.960000   144842.180000    298932.675000  139765.977500
# max    165349.200000   182645.560000    471784.100000  192261.830000

# %%
#Printing first 6 rows .
Stps
# Out:
#     R&D Spend  Administration  Marketing Spend       State     Profit
# 0   165349.20       136897.80        471784.10    New York  192261.83
# 1   162597.70       151377.59              NaN  California        NaN
# 2   153441.51       101145.55        407934.54     Florida  191050.39
# 3   144372.41       118671.85        383199.62    New York        NaN
# 4   142107.34        91391.77        366168.42     Florida  166187.94
# 5   131876.90             NaN        362861.36         NaN  156991.12
# 6         NaN       147198.87        127716.82  California  156122.51
# 7   130298.13       145530.06        323876.68     Florida        NaN
# 8   120542.52       148718.95        311613.29         NaN  152211.77
# 9   123334.88       108679.17        304981.62  California  149759.96
# 10  101913.08       110594.11        229160.95     Florida  146121.95
# 11  100671.96        91790.61        249744.55  California        NaN
# 12   93863.75       127320.38        249839.44     Florida  141585.52
# 13   91992.39       135495.07             0.00  California  134307.35
# 14  119943.24       156547.42        256512.92     Florida  132602.65
# 15        NaN       122616.84        261776.23    New York  129917.04
# 16   78013.11             NaN        264346.06  California        NaN
# 17   94657.16       145077.58        282574.31    New York  125370.37
# 18   91749.16       114175.79        294919.57     Florida  124266.90
# 19   86419.70       153514.11             0.00    New York        NaN
# 20   76253.86       113867.30        298664.47  California  118474.03
# 21   78389.47       153773.43        299737.29    New York  111313.02
# 22   73994.56       122782.75        303319.26     Florida        NaN
# 23   67532.53       105751.03        304768.73     Florida        NaN
# 24   77044.01        99281.34        140574.81    New York  108552.04
# 25        NaN       139553.16        137962.62  California  107404.34
# 26   75328.87       144135.98        134050.07     Florida  105733.54
# 27   72107.60       127864.55        353183.81    New York        NaN
# 28   66051.52       182645.56        118148.20     Florida  103282.38
# 29   65605.48             NaN        107138.38    New York        NaN
# 30   61994.48       115641.28         91131.24     Florida   99937.59
# 31   61136.38       152701.92         88218.23    New York        NaN
# 32   63408.86       129219.61         46085.25  California   97427.84
# 33   55493.95       103057.49              NaN     Florida   96778.92
# 34        NaN       157693.92        210797.67  California   96712.80
# 35   46014.02        85047.44        205517.64    New York        NaN
# 36   28663.76       127056.21        201126.82     Florida   90708.19
# 37   44069.95        51283.14        197029.42  California   89949.14
# 38   20229.59        65947.93        185265.10    New York   81229.06
# 39   38558.51             NaN        174999.30  California   81005.76
# 40   28754.33       118546.05        172795.67         NaN        NaN
# 41   27892.92        84710.77        164470.71     Florida   77798.83
# 42        NaN        96189.63        148001.11  California   71498.49
# 43   15505.73       127382.30         35534.17    New York   69758.98
# 44   22177.74       154806.14         28334.72  California        NaN
# 45    1000.23       124153.04          1903.93    New York        NaN
# 46    1315.46       115816.21        297114.46     Florida   49490.75
# 47       0.00       135426.92             0.00  California   42559.73
# 48     542.05        51743.15             0.00         NaN        NaN
# 49       0.00       116983.80         45173.06  California   14681.40

# %%
#sorting values of column Profit 
Stps.sort_values('Profit',ascending=False,inplace=True) 
#I will set 'State' as index as i won't be able to use interpolate function for this column as it is string
Stps.set_index('State',inplace=True)  
Stps.head()
# Out:
#             R&D Spend  Administration  Marketing Spend     Profit
# State
# New York    165349.20       136897.80        471784.10  192261.83
# Florida     153441.51       101145.55        407934.54  191050.39
# Florida     142107.34        91391.77        366168.42  166187.94
# NaN         131876.90             NaN        362861.36  156991.12
# California        NaN       147198.87        127716.82  156122.51

# %% [markdown]
# ### Data Cleaning

# %%
if Stps.isnull().any(axis = None): 
    print("\nPreview of data with null values:\n") 
    print(Stps[Stps.isnull().any(axis=1)].head())
# Out:
# Preview of data with null values:
#
#             R&D Spend  Administration  Marketing Spend     Profit
# State
# NaN         131876.90             NaN        362861.36  156991.12
# California        NaN       147198.87        127716.82  156122.51
# New York          NaN       122616.84        261776.23  129917.04
# California        NaN       139553.16        137962.62  107404.34
# Florida      55493.95       103057.49              NaN   96778.92

# %%
#Counting MISSING Vvalues
x=Stps.isnull().sum()
#Counting total missing values in entire DataFrame
x1=Stps.isnull().sum().sum()
print("Counting the number of NaN values in columns\n",x)
print("\nTotal NaN values in Dataframe:",x1)
# Out:
# Counting the number of NaN values in columns
#  R&D Spend           5
# Administration      4
# Marketing Spend     2
# Profit             16
# dtype: int64
#
# Total NaN values in Dataframe: 27

# %%
#Filling Nan Values
Stps.interpolate(method = 'linear', axis = 0,inplace=True) #can i use interpolate used to fill NaN based on previous columns

# %% [markdown]
# ## Adding a new Column

# %%
#I want to find total SG&A cost spent on Production of service
Stps['Total Spent']=Stps['R&D Spend']+Stps['Administration']+Stps['Marketing Spend']
Stps
# Out:
#              R&D Spend  Administration  Marketing Spend     Profit  Total Spent
# State
# New York    165349.200      136897.800        471784.10  192261.83   774031.100
# Florida     153441.510      101145.550        407934.54  191050.39   662521.600
# Florida     142107.340       91391.770        366168.42  166187.94   599667.530
# NaN         131876.900      119295.320        362861.36  156991.12   614033.580
# California  126209.710      147198.870        127716.82  156122.51   401125.400
# NaN         120542.520      148718.950        311613.29  152211.77   580874.760
# California  123334.880      108679.170        304981.62  149759.96   536995.670
# Florida     101913.080      110594.110        229160.95  146121.95   441668.140
# Florida      93863.750      127320.380        249839.44  141585.52   471023.570
# California   91992.390      135495.070             0.00  134307.35   227487.460
# Florida     119943.240      156547.420        256512.92  132602.65   533003.580
# New York    107300.200      122616.840        261776.23  129917.04   491693.270
# New York     94657.160      145077.580        282574.31  125370.37   522309.050
# Florida      91749.160      114175.790        294919.57  124266.90   500844.520
# California   76253.860      113867.300        298664.47  118474.03   488785.630
# New York     78389.470      153773.430        299737.29  111313.02   531900.190
# New York     77044.010       99281.340        140574.81  108552.04   316900.160
# California   76186.440      139553.160        137962.62  107404.34   353702.220
# Florida      75328.870      144135.980        134050.07  105733.54   353514.920
# Florida      66051.520      182645.560        118148.20  103282.38   366845.280
# Florida      61994.480      115641.280         91131.24   99937.59   268767.000
# California   63408.860      129219.610         46085.25   97427.84   238713.720
# Florida      55493.950      103057.490        128441.46   96778.92   286992.900
# California   42078.855      157693.920        210797.67   96712.80   410570.445
# Florida      28663.760      127056.210        201126.82   90708.19   356846.790
# California   44069.950       51283.140        197029.42   89949.14   292382.510
# New York     20229.590       65947.930        185265.10   81229.06   271442.620
# California   38558.510       75329.350        174999.30   81005.76   288887.160
# Florida      27892.920       84710.770        164470.71   77798.83   277074.400
# California   21699.325       96189.630        148001.11   71498.49   265890.065
# New York     15505.730      127382.300         35534.17   69758.98   178422.200
# Florida       1315.460      115816.210        297114.46   49490.75   414246.130
# California       0.000      135426.920             0.00   42559.73   135426.920
# California       0.000      116983.800         45173.06   14681.40   162156.860
# California  162597.700      151377.590        214186.34   14681.40   528161.630
# New York    144372.410      118671.850        383199.62   14681.40   646243.880
# Florida     130298.130      145530.060        323876.68   14681.40   599704.870
# California  100671.960       91790.610        249744.55   14681.40   442207.120
# California   78013.110      122652.360        264346.06   14681.40   465011.530
# New York     86419.700      153514.110             0.00   14681.40   239933.810
# Florida      73994.560      122782.750        303319.26   14681.40   500096.570
# Florida      67532.530      105751.030        304768.73   14681.40   478052.290
# New York     72107.600      127864.550        353183.81   14681.40   553155.960
# New York     65605.480      140283.235        107138.38   14681.40   313027.095
# New York     61136.380      152701.920         88218.23   14681.40   302056.530
# New York     46014.020       85047.440        205517.64   14681.40   336579.100
# NaN          28754.330      118546.050        172795.67   14681.40   320096.050
# California   22177.740      154806.140         28334.72   14681.40   205318.600
# New York      1000.230      124153.040          1903.93   14681.40   127057.200
# NaN            542.050       51743.150             0.00   14681.40    52285.200

# %%
#I don't want 'State ias my index anymore so i will make it into column'
Stps.reset_index(level=0,inplace=True)
Stps.head()
# Out:
#         State  R&D Spend  ...     Profit  Total Spent
# 0    New York  165349.20  ...  192261.83    774031.10
# 1     Florida  153441.51  ...  191050.39    662521.60
# 2     Florida  142107.34  ...  166187.94    599667.53
# 3         NaN  131876.90  ...  156991.12    614033.58
# 4  California  126209.71  ...  156122.51    401125.40
#
# [5 rows x 6 columns]

# %% [markdown]
# ## I want to calculate the percentage of profit of total amount spent  I will add one more column of it

# %%
Stps['Percentage_Profit']=(Stps['Profit']/Stps['Total Spent'])*100
Stps['State'].fillna(method='ffill',axis=0,inplace=True)
Stps
# Out:
#          State   R&D Spend  ...  Total Spent  Percentage_Profit
# 0     New York  165349.200  ...   774031.100          24.839032
# 1      Florida  153441.510  ...   662521.600          28.836855
# 2      Florida  142107.340  ...   599667.530          27.713346
# 3      Florida  131876.900  ...   614033.580          25.567188
# 4   California  126209.710  ...   401125.400          38.921123
# 5   California  120542.520  ...   580874.760          26.203888
# 6   California  123334.880  ...   536995.670          27.888486
# 7      Florida  101913.080  ...   441668.140          33.084105
# 8      Florida   93863.750  ...   471023.570          30.059116
# 9   California   91992.390  ...   227487.460          59.039452
# 10     Florida  119943.240  ...   533003.580          24.878379
# 11    New York  107300.200  ...   491693.270          26.422375
# 12    New York   94657.160  ...   522309.050          24.003101
# 13     Florida   91749.160  ...   500844.520          24.811472
# 14  California   76253.860  ...   488785.630          24.238444
# 15    New York   78389.470  ...   531900.190          20.927426
# 16    New York   77044.010  ...   316900.160          34.254334
# 17  California   76186.440  ...   353702.220          30.365752
# 18     Florida   75328.870  ...   353514.920          29.909216
# 19     Florida   66051.520  ...   366845.280          28.154207
# 20     Florida   61994.480  ...   268767.000          37.183728
# 21  California   63408.860  ...   238713.720          40.813674
# 22     Florida   55493.950  ...   286992.900          33.721712
# 23  California   42078.855  ...   410570.445          23.555714
# 24     Florida   28663.760  ...   356846.790          25.419366
# 25  California   44069.950  ...   292382.510          30.764200
# 26    New York   20229.590  ...   271442.620          29.924947
# 27  California   38558.510  ...   288887.160          28.040623
# 28     Florida   27892.920  ...   277074.400          28.078679
# 29  California   21699.325  ...   265890.065          26.890245
# 30    New York   15505.730  ...   178422.200          39.097702
# 31     Florida    1315.460  ...   414246.130          11.947185
# 32  California       0.000  ...   135426.920          31.426344
# 33  California       0.000  ...   162156.860           9.053826
# 34  California  162597.700  ...   528161.630           2.779717
# 35    New York  144372.410  ...   646243.880           2.271805
# 36     Florida  130298.130  ...   599704.870           2.448104
# 37  California  100671.960  ...   442207.120           3.320028
# 38  California   78013.110  ...   465011.530           3.157212
# 39    New York   86419.700  ...   239933.810           6.118938
# 40     Florida   73994.560  ...   500096.570           2.935713
# 41     Florida   67532.530  ...   478052.290           3.071087
# 42    New York   72107.600  ...   553155.960           2.654116
# 43    New York   65605.480  ...   313027.095           4.690137
# 44    New York   61136.380  ...   302056.530           4.860481
# 45    New York   46014.020  ...   336579.100           4.361946
# 46    New York   28754.330  ...   320096.050           4.586561
# 47  California   22177.740  ...   205318.600           7.150546
# 48    New York    1000.230  ...   127057.200          11.554953
# 49    New York     542.050  ...    52285.200          28.079457
#
# [50 rows x 7 columns]

# %%
#let's check if there are still any null values left
print(Stps.isnull().any())
print('\nAs we can see there is no null value left')
# Out:
# State                False
# R&D Spend            False
# Administration       False
# Marketing Spend      False
# Profit               False
# Total Spent          False
# Percentage_Profit    False
# dtype: bool
#
# As we can see there is no null value left

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# ### Bar graph counts the number of startups in each state and shows State with maximum startups

# %%
sb.countplot(x='State',data=Stps)

# %% [markdown]
# ### BarPlot using groupby function
# This Graph shows the state that made maximum percentage profit and shows its mean on y axis

# %%
#Use of Groupby function
a=pd.DataFrame(Stps.groupby(['State'])['Percentage_Profit'].sum());
a=a.rename(columns={'Percentage_Profit':'Sum of Percentage Profits'});
print(a)
sb.barplot(x=a.index,y=a['Sum of Percentage Profits'],data=a);
# Out:
#             Sum of Percentage Profits
# State
# California                 413.609274
# Florida                    397.819456
# New York                   268.647311

# %% [markdown]
# ## Heat Map
# A correlation value of 1 tells us there is a high correlation and a correlation of 0 tells us that the data is not correlated at all.

# %%
Stps.corr()
# Out:
#                    R&D Spend  Administration  ...  Total Spent  Percentage_Profit
# R&D Spend           1.000000        0.266947  ...     0.830793          -0.001326
# Administration      0.266947        1.000000  ...     0.208253          -0.120067
# Marketing Spend     0.645488       -0.058450  ...     0.943168          -0.240153
# Profit              0.489813        0.046579  ...     0.429078           0.732586
# Total Spent         0.830793        0.208253  ...     1.000000          -0.205760
# Percentage_Profit  -0.001326       -0.120067  ...    -0.205760           1.000000
#
# [6 rows x 6 columns]

# %%
# Heatmap
sb.heatmap(Stps.corr())

# %% [markdown]
# ### Histogram

# %%
sb.distplot(Stps.Percentage_Profit)

# %% [markdown]
# ### Joint Graph

# %%
sb.jointplot(x='Marketing Spend', y='R&D Spend', data=Stps,kind='hex')

# %% [markdown]
# ### Scatterplot Graph

# %%
sb.lmplot(x='Marketing Spend', y='R&D Spend', data=Stps)

# %% [markdown]
# ### Pie Chart
# #### Below given Pie Chart shows the percentage of amount spent on Administration,R&D and on Marketing with respect to eachother

# %%
Stps.mean()
# Out:
# R&D Spend             73513.690600
# Administration       121347.316700
# Marketing Spend      199653.688400
# Profit                80959.130600
# Total Spent          394514.695700
# Percentage_Profit        21.601521
# dtype: float64

# %%
print("""Below given Pie Chart shows the percentage of amount spent on Administration,
R&D and on Marketing with respect to eachother""")
labels = 'R&D Spend  ', 'Administration', 'Marketing Spend'
sizes = [ 73513.690600,121347.316700, 199653.688400]
colors = ['gold', 'yellowgreen', 'lightcoral']
explode = (0.4, 0, 0)
plt.pie(sizes, explode=explode, labels=labels, colors=colors,autopct='%1.1f%%', shadow=False)

plt.axis('equal')
plt.show()
# Out:
# Below given Pie Chart shows the percentage of amount spent on Administration,
# R&D and on Marketing with respect to eachother

# %%
sb.barplot(x='Percentage_Profit',y='Profit',data=Stps)

# %%
sb.violinplot(y="Percentage_Profit", x="State", data=Stps,palette='rainbow')

# %%
import warnings
warnings.filterwarnings('ignore')
sb.pairplot(Stps)

# %%
sb.pairplot(Stps,hue='Percentage_Profit')
